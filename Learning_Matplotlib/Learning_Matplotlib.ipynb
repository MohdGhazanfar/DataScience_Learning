# %% [markdown]
# # Matplotlib
# ---------------------
# **Matplotlib** is a Python library used to create charts and graphs.
#
# Before you start working with Matplotlib, we need to **import** it into our Python environment.

# %%
# Import Matplotlib in our Python environment

from matplotlib import pyplot as plt

# %% [markdown]
# ## Basic Line Plot
# Line graphs are basic that help visualise how a variable changes over time. Some possible data that would be displayed with a line graph:
# - average prices of gasoline over the past decade
# - weight of an individual over the past couple of months
# - average temperature along a line of longitude over different lattitudes
#
# The following code will create a simple graph using **.plot()** and display it using **.show()**:

# %%
x_values = [0, 1, 2, 3, 4]
y_values = [0, 1, 2, 3, 4]
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# **x_values** : is a variable holding a list of x-values for each point on our line graph
#
# **y_values** : is a variable holding a list of y-values for each point on our line graph
#
# **plt**      : is the name we have given to the Matplotlib module we have imported at the top of the code
#
# **plt.plot(x_values, y_values)** : will create the line graph
#
# **plt.show()** : will actually display the graph
#
# #### Example
#
# We are going to make a simple graph representing someone's spending on lunch over the past week. There are two lists defined **days** and **money_spent**:

# %%
days = [0, 1, 2, 3, 4, 5, 6]
money_spent = [10, 12, 12, 10, 14, 22, 24]

plt.plot(days, money_spent)
plt.show()

# %% [markdown]
# ## Basic Line Plot 2
#
# We can have multiple line plots displayed on the same set of axes. This can be very useful if we want to compare two datasets with the same scale and axis categories. Matplotlib will automatically place the two lines on the same axes and give them different colors if you call **plt.plot()** twice.
#
# Taking the previous example, we add a friend's lunch spending for comparison:

# %%
# Days of the week:
days = [0, 1, 2, 3, 4, 5, 6]

# Your Money:
money_spent = [10, 12, 12, 10, 14, 22, 24]

# Your Friend's Money:
money_spent_2 = [11, 14, 15, 15, 22, 21, 12]

# Plot your money:
plt.plot(days, money_spent)

# Plot your friend's money:
plt.plot(days, money_spent_2)

# Display the result:
plt.show()

# %% [markdown]
# #### Example

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

plt.plot(time, revenue)
plt.plot(time, costs)
plt.show()

# %% [markdown]
# ## Linestyles
#
# We can specify a different color for a line by using the keyword **color** with either an HTML color name or a HEX code:

# %%
plt.plot(days, money_spent, color='green')
plt.plot(days, money_spent_2, color='#AAAAAA')
plt.show()

# %% [markdown]
# We can also make a line dotted or dashed using keyword **linestyle**:

# %%
# Dashed
plt.plot(x_values, y_values, linestyle='--')
plt.show()

# %%
# Dotted:
plt.plot(x_values, y_values, linestyle=':')
plt.show()

# %%
# No line:
plt.plot(x_values, y_values, linestyle='')
plt.show()

# %% [markdown]
# We can also add a marker using the keyword **marker**:

# %%
# A circle:
plt.plot(x_values, y_values, marker='o')
plt.show()

# %%
# A square:
plt.plot(time, revenue, marker='s')

# A star:
plt.plot(time, costs, marker='*')

plt.show()

# %% [markdown]
# ## Axis and Labels
#
# It can be useful to zoom in or out of the plot, especially if there is some detail we want to address. To zoom, we can use **plt.axis()**. We use **plt.axis()** by feeding it a list as input. This should contain:
# 1. The minimum x-value displayed
# 2. The maximum x-value displayed
# 3. The minimum y-value displayed
# 4. The maximum y-value displayed
#
# **Example:** if we want to display a plot from x=0 to x=3 and from y=2 to y=5 we would call **plt.axis([0, 3, 2, 5])**

# %%
x=[0, 1, 2, 3, 4]
y=[0, 1, 3, 9, 16]
plt.plot(x, y)
plt.show()

# %%
x=[0, 1, 2, 3, 4]
y=[0, 1, 3, 9, 16]
plt.plot(x, y)
plt.axis([0, 3, 2, 5])
plt.show()

# %% [markdown]
# ## Labeling the Axes
#
# To label the x- and y-axes we use **plt.xlabel()** and **plt.ylabel()**. The plot title can be set by using **plt.title()**.
#
# **Example**: Below we look at an example for money spent on drinking coffee over the last 12 years

# %%
x=range(12)
y = [3000, 3005, 3010, 2900, 2950, 3050, 3000, 3100, 2980, 2980, 2920, 3010]
plt.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Dollars spent on Coffee ($)')
plt.title('My Last 12yrs of Coffee Drinking')
plt.show()

# %% [markdown]
# ## Subplots
#
# To display two lines side-by-side, rather than in the same set of x- and y-axes we use **subplots**. When we have multiple axes in the same picture, we call each set of axes a ***subplot***. The picture or object that contains all of the subplots is called a ***figure***.
#
# We can have many different subplots in the same figure, and we can lay them out in many different ways. Our layouts have rows and columns of subplots. For instance, the following figure has six subplots split into 2 rows and 3 columns:
# ![image.png](attachment:image.png)
#
# We can create subplots using **.subplot()**
#
# The command **plt.subplot()** needs three arguments to be passed into it:
# - The number of rows of subplots
# - The number of columns of subplots
# - The index of the subplot we want to create
#
# For instance, the command **plt.subplot(2, 3, 4)** would create "Subplot 4" from the figure above.
#
# Any **plt.plot()** that comes after **plt.subplot()** will create a line plot in the specified subplot for instance:

# %%
# Data sets
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

# First Subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, color='green')
plt.title('First Subplot')

# Second Subplot
plt.subplot(1, 2, 2)
plt.plot(x, y, color='steelblue')
plt.title('Second Subplot')

# Display both subplots
plt.show()

# %% [markdown]
# #### Example

# %%
months = range(12)
temperature = [36, 36, 39, 52, 61, 72, 77, 75, 68, 57, 48, 48]
flights_to_hawaii = [1200, 1300, 1100, 1450, 850, 750, 400, 450, 400, 860, 990, 1000]

# temperature vs months
plt.subplot(1,2,1)
plt.plot(months, temperature)
plt.xlabel('Month')
plt.ylabel('Temperature (F)')
plt.title('Temperature over the Year')

# flights to hawaii vs temperature
plt.subplot(1,2,2)
plt.plot(temperature, flights_to_hawaii, marker='o')
plt.xlabel('Temperature (F)')
plt.ylabel('Flight Timing')
plt.title('Hawaii Flights and Temperature')

plt.show()

# %% [markdown]
# ## Subplots Part 2
#
# When we put multiple subplots together, some elements can overlap and make the figure unreadable as seen in the previous example.
#
# We can customize the spacing between our subplots to make sure the figure we create is visible and easy to understand. To do this, we use the **plt.subplots_adjust()** command. **.subplots_adjust()** has some keyword arguments that can move your plots within the figure:
# - **left** : the left-side margin, with a default of 0.125. You can increase this number to make room for a y-axis label
# - **right** : the right-side margin, with a default of 0.9. You can increase this to make more room for the figure, or decrease it to make room for a legend
# - **bottom** : the bottom margin, with a default of 0.1. You can increase this to make room for tick mark labels or an x-axis label
# - **top** : the top margin, with a default of 0.9
# - **wspace** : the horizontal space between adjacent subplots, with a default of 0.2
# - **hspace** :  the vertical space between adjacent subplots, with a default of 0.2
#
# #### Example
# We are going to create a figure that has two rows of subplots. It should have:
# - one subplot in the top row
# - two subplots in the bottom row
# ![image.png](attachment:image.png)

# %%
x = range(7)
straight_line = [0, 1, 2, 3, 4, 5, 6]
parabola = [0, 1, 4, 9, 16, 25, 36]
cubic = [0, 1, 8, 27, 64, 125, 216]

# Top Plot (Index 1)
plt.subplot(2, 1, 1)
plt.plot(x, straight_line)
plt.title('Star Graph')

# Left Bottom Plot (Index 3)
plt.subplot(2, 2, 3)
plt.plot(x, parabola)
plt.title('Square Graph')

# Bottom Right Plot (Index 4)
plt.subplot(2, 2, 4)
plt.plot(x, cubic)
plt.title('Triangle Graph')

# Subplot Adjust
plt.subplots_adjust(wspace=0.35, bottom=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ## Legends
#
# We can label our graphs using legends by the command **plt.legend()**.
#
# The **legend** method takes a ***list*** with the labels to display.

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
plt.legend(['parabola', 'cubic'])
plt.show()

# %% [markdown]
# The command **plt.legend()** can also take a keyword argument **loc**, which will position the legend on the figure. The position values **loc** accepts:
#
#        Number Code     String
#             0           best
#             1           upper right
#             2           upper left
#             3           lower left
#             4           lower right
#             5           right
#             6           center left
#             7           center right
#             8           lower center
#             9           upper center
#             10          center
# **Note:** If you decide not to set a value for **loc** it will default to choosing the "best" location.

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
plt.legend(['parabola', 'cubic'], loc=6)
plt.show()

# %% [markdown]
# Sometimes, it's easier to label each line as we create it. If we want, we can use the keyword **label** inside of the **plt.plot()**. If we choose to do this, we don't pass any labels into **plt.legend()**

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16],
         label="parabola")
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64],
         label="cubic")
plt.legend(loc=6) # Still need this command! We don't pass labels but can still give location 
plt.show()

# %% [markdown]
# #### Example
# We plott three lines that represent the temperatures over the past year in three locations:
# - Hyrule (hyrule)
# - Kakariko (kakariko)
# - Gerudo Valley (gerudo)

# %%
months = range(12)
hyrule = [63, 65, 68, 70, 72, 72, 73, 74, 71, 70, 68, 64]
kakariko = [52, 52, 53, 68, 73, 74, 74, 76, 71, 62, 58, 54]
gerudo = [98, 99, 99, 100, 99, 100, 98, 101, 101, 97, 98, 99]

plt.plot(months, hyrule)
plt.plot(months, kakariko)
plt.plot(months, gerudo)
plt.xlabel('months')
plt.ylabel('temperature (F)')
plt.title('Temperature Graph')

legend_labels = ["Hyrule", "Kakariko", "Gerudo Valley"]

plt.legend(legend_labels)

plt.show()

# %% [markdown]
# ## Modify Ticks

# %% [markdown]
# So far we have started our commands with **plt.**. We can modify tick marks, and try something bit different.
#
# Because our plots can have multiple subplots, we have to specify which ones we want to modify. In order to do that, we call **plt.subplot()** in a different way:
#
# ax = plt.subplot(1,1,1)
#
# **ax** is an axes object, and it lets us modify axes belonging to a specific subplot.
#
# Even if we only have one subplot, when we want to modify the ticks, we will need to start by calling either:
# - **ax = plt.subplot(1, 1, 1)**
#
# OR
# - **ax = plt.subplot()**
#
# **Note:** *Ticks are the markers denoting data points on axes.*
#
# Suppose we wanted to set our x-ticks to be at 1, 2, and 4. We would use the following code:

# %%
ax = plt.subplot()
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
ax.set_xticks([1, 2, 4])
plt.show()


# basically what we are doing in this example is changing the x-axes tick labels
# as you can see the numbers 1, 2, and 4

# %% [markdown]
# We can also modify the y-ticks by using **ax.set_yticks()**.
#
# If we want special labels (such as string), we can use the command **ax.set_xticklabels()** OR **ax.set_ysticklabels()**.
#
# #### Example
# If we want to have a y-axis with ticks at 0.1, 0.6, and 0.8, but label them 10%, 60%, and 80% respectively. To do this we use the following commands:

# %%
ax = plt.subplot()
plt.plot([1, 3, 3.5], [0.1, 0.6, 0.8], 'o')
ax.set_yticks([0.1, 0.6, 0.8])
ax.set_yticklabels(['10%', '60%', '80%'])
plt.show()

# %% [markdown]
# #### Example
#
# Let’s imagine we are working for a company called Dinnersaur, that delivers dinners to people who don’t want to cook. Dinnersaur recently started a new service that is subscription-based, where users sign up for a whole year of meals, instead of buying meals on-demand.
#
# We have plotted a line representing the proportion of users who have switched over to this new service since it was rolled out in January. First, save the set of axes in a variable called ax. We will use ax to set the x- and y-ticks and labels to make this graph easier to read.

# %%
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep","Oct", "Nov", "Dec"]
months = range(12)
conversion = [0.05, 0.08, 0.18, 0.28, 0.4, 0.66, 0.74, 0.78, 0.8, 0.81, 0.85, 0.85]
plt.xlabel("Months")
plt.ylabel("Conversion")
plt.plot(months, conversion)

# save the set of axes in a variable called ax which we use to set the x- and y-ticks
# ax = plt.subplot()
ax.set_xticks(months)
ax.set_xticklabels(month_names)
ax.set_yticks([0.10, 0.25, 0.5, 0.75])
ax.set_yticklabels(['10%', '25%', '50%', '75%'])


plt.show()

# %% [markdown]
# ## Figures

# %% [markdown]
# When we’re making lots of plots, it’s easy to end up with lines that have been plotted and not displayed. If we’re not careful, these “forgotten” lines will show up in your new plots. In order to be sure that you don’t have any stray lines, you can use the command **plt.close('all')** to clear all existing plots before you plot a new one.
#
# Sometimes, we would rather have two separate figures. We can use the command **plt.figure()** to create new figures and size them how we want. We can add the keyword **figsize=(width, height)** to set the size of the figure, in inches. We use parentheses (**(** and **)**) to pass in the width and height, which are separated by a comma (**,**).

# %%
plt.figure(figsize=(4,10))
plt.plot([0, 1, 2, 3, 4], [5, 10, 15, 20, 25])
plt.show()

# the figure looks tall and skinny as below:

# %% [markdown]
# Once we’ve created a figure, we might want to save it so that we can use it in a presentation or a website. We can use the command **plt.savefig()** to save out to many different file formats, such as png, svg, or pdf. After plotting, we can call **plt.savefig('name_of_graph.png')**:

# %%
plt.figure(figsize=(4,10))
plt.plot(x, parabola)
plt.savefig('tall_and_narrow.png')

# %% [markdown]
# This will save **tall_and_narrow.png** to our file system in the folder.

# %% [markdown]
# #### Example
#
# We create a figure and plot **word_length** against **years**. This dataset represents the lenghts of the winning words of the Scripps National Spelling Bee over 11 years. We save this figure in a file called **'winning_word_lengths.png**.
#
# We create another figure with 7inches of width and 3 inches of height and plot **power_generated** against **years**. This dataset represents the power generated by nuclear plants in the United States over 11 years. We save this figures in a file called **'power_generated.png'**

# %%
word_length = [8, 11, 12, 11, 13, 12, 9, 9, 7, 9]
power_generated = [753.9, 768.8, 780.1, 763.7, 788.5, 782, 787.2, 806.4, 806.2, 798.9]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

plt.close('all')
plt.plot(years, word_length)
plt.title('Winning Word Lengths')
plt.savefig('winning_word_lengths.png')


plt.figure(figsize=(7,3))
plt.plot(years, power_generated)
plt.title('Power Generated')
plt.savefig('power_generated.png')

plt.show()

# %% [markdown]
# -------------
# # Different Plot Types
#
# ## Simple Bar Chart
#
# The **plt.bar** function allows you to create simple bar charts to compare multiple categories of data.
#
# Some possible data that would be displayed with a bar chart:
# - x-axis — famous buildings, y-axis — heights
# - x-axis — different planets, y-axis — number of days in the year
# - x-axis — programming languages, y-axis — lines of code written by you
#
# You call **plt.bar** with two arguments:
# - the x-values — a list of x-positions for each bar
# - the y-values — a list of heights for each bar
#
# In most cases, we will want our x-values to be a list that looks like **[0, 1, 2, 3,...]** and has the same number of elements as the y-values list. Below is an example of how we can use the length of the list for the x-values:

# %%
from matplotlib import pyplot as plt

# comparing the number of days in a year on the different planets
days_in_year = [88, 225, 365, 687, 4333, 10756, 30687, 60190, 90553]
plt.bar(range(len(days_in_year)), days_in_year)
plt.show()

# %% [markdown]
# #### Example
# We look into some data for a cafe called MatplotSip and compare the sales of different beverages on a given day. Below we have a list of drink categories and a list of numbers representing the sales of each drink over the past month

# %%
drinks =  ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales =  [91, 76, 56, 66, 52, 27]

plt.bar(range(len(drinks)), sales)
plt.show()

# %% [markdown]
# ## Simple Bar Chart 2
# Here we learn how to customise our bar charts.
#
# 1. Create an axes object:
#
#         ax = plt.subplot()
#
#
# 2. Set the x-tick positions using a list of numbers:
#
#         ax.set_xticks([0, 1, 2, 3, 4, 5, 6, 7, 8])
#
#
# 3. Set the x-tick labes using a list of strings:
#
#         ax.set_xtick(['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto'])
#
#
# 4. If your labels are particularly long, you can use the rotation keyword to rotate your labels by a specified number of degrees:
#
#         ax.set_xticklabels(['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto'], rotation=30)
#
# **Note:** We have to set the x-ticks before we set the x-labels because the default ticks won’t necessarily be one tick per bar, especially if we’re plotting a lot of bars. If we skip setting the x-ticks before the x-labels, we might end up with labels in the wrong place.
#
# 5. We can label the x-axis (**plt.xlabel**) and y-axis (**plt.ylabel**) as well

# %%
plt.bar(range(len(drinks)), sales)
ax3 = plt.subplot()
ax3.set_xticks(range(len(drinks)))
ax3.set_xticklabels(drinks, rotation = 20)
plt.show()
# Out:
# /Users/MoG/opt/anaconda3/envs/learning_data_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ## Side-by-Side Bars
#
# We can use a bar chart to compare two sets of data with the same types of axis values. To do this, we plot two sets of bars next to each other, so that the values of each category can be compared.
#
# For example, here is a chart with side-by-side bars for the populations of the United States and China over the age of 65 (in percentages):
# ![image.png](attachment:image.png)
#
# In the graph above, there are 7 sets of bars, with 2 bars in each set. Each bar has a width of 0.8 (the default width for all bars in Matplotlib).
# - If our first blue bar is at x=0, then we want the next blue bar to be at x=2, and the next to be at x=4, etc.
# - Our first orange bar should be at x=0.8 (so that it is touching the blue bar), and the next orange bar should be at x=2.8, etc.

# %%
# China Data (blue bars)
n = 1   # This is our first dataset (out of 2)
t = 2   # Number of datasets
d = 7   # Number of sets of bars
w = 0.8 # Width of each bar

X_values1 = [t*element + w*n for element in range(d)]

# %% [markdown]
# This just generated the first set of x_values. To generate the second set, paste the code again, but change **n** to 2, because this is the second dataset:

# %%
# US Data (orange bars)
n = 2   # This is our first dataset (out of 2)
t = 2   # Number of datasets
d = 7   # Number of sets of bars
w = 0.8 # Width of each bar

X_values2 = [t*element + w*n for element in range(d)]

# %% [markdown]
# #### Example
# We take the previous example of the MatplotSip cafe, where a second location opened up. The owners want to compare the drink choices of the clientele at the two different locations. To do this we want the sales of each drink plotted on the same axes.

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]

n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar

store1_x = [t*element + w*n for element
             in range(d)]

n = 2  # This is our second dataset (out of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar

store2_x = [t*element + w*n for element
             in range(d)]

plt.bar(store1_x, sales1)
plt.bar(store2_x, sales2)

plt.show()

# %% [markdown]
# ## Stacked Bars
#
# If we want to compare two sets of data while preserving knowledge of the total between them, we can also stack the bars instead of putting them side by side.
#
# For instance, if someone was plotting the hours they’ve spent on entertaining themselves with video games and books in the past week, and wanted to also get a feel for total hours spent on entertainment, they could create a stacked bar chart:
#
# ![image.png](attachment:image.png)
# We do this by using the keyword **bottom**. The top set of bars will have bottom set to the heights of the other set of bars. So the first set of bars is plotted normally:

# %%
# first set of bars is plotted normally
video_game_hours = [1, 2, 2, 1, 2]

plt.bar(range(len(video_game_hours)),video_game_hours) 

# second set of bars has bottom specified
book_hours = [2, 3, 4, 2, 1]

plt.bar(range(len(book_hours)), book_hours, bottom=video_game_hours)

plt.show()

# %% [markdown]
# #### Example
# We take the MatplotSlip cafe example again

# %%
plt.bar(range(len(drinks)), sales1)
plt.bar(range(len(drinks)), sales2, bottom=sales1)
plt.legend(['Location 1', 'Location 2'])
plt.show()

# %% [markdown]
# ## Error Bars
#
# To visually communicate with some sort of uncertainity in the heights of bars, we use Error bars for some cases like:
# - The average number of students in a 3rd grade classroom is 30, but some classes have as few as 18 and others have as many as 35 students
# - We measured that the weight of a certain fruit was 35g, but we know that our scale isn’t very precise, so the true weight of the fruit might be as much as 40g or as little as 30g.
# - The average price of a soda is USD1.00, but we also want to communicate that the standard deviation is USD0.20.
# ![image.png](attachment:image.png)
#
# Each of the black lines is called an ***error bar***. The taller the bar is, the more uncertain we are about the height of the blue bar. The horizontal lines at the top and bottom are called ***caps***. They make it easier to read the error bars.
#
# If we wanted to show an error of +/- 2, we would add the keyword **yerr=2** to our **plt.bar** command. To make the caps wide and easy to read, we would add the keyword **capsize=10**:

# %%
values = [10, 13, 11, 15, 20]
yerr = 2
plt.bar(range(len(values)), values, yerr=yerr, capsize=10)
plt.show()

# %% [markdown]
# If we want a different amount of error for each bar, we can make **yerr** equal to a list rather than a single number:

# %%
values =[10, 13, 11, 15, 20]
yerr= [1, 3, 0.5, 2, 4]
plt.bar(range(len(values)), values, yerr=yerr, capsize=10)
plt.show()

# %% [markdown]
# **NOTE:**: Like the list of x-axis labels, Matplotlib reads this in the same order as the list of y-values. So, the first index of your error list should correspond to the first index of your y-values list, the second index of your error list should correspond to the second index of your y-values list, and so on.

# %% [markdown]
# #### Example
# For someone learning about the different drink types at MatplotSip, a bar chart of milk amounts in each maybe useful. Below is **ounces_of_milk** list which contains the amount of milk in each 12oz drink in the **drinks** list:

# %%
ounces_of_milk = [6, 9, 4, 0, 9, 0]
error = [0.6, 0.9, 0.4, 0, 0.9, 0]

plt.bar(range(len(drinks)), ounces_of_milk, yerr = error, capsize=10)

plt.show()

# %% [markdown]
# ## Fill Between (Line Graph)
#
# In the above example, we displayed errors on bar chart using error bars. To do this on a line graph, we use **plt.fill_between** to shade error.
#
# The function takes three arguments:
# 1. **x-values** :             this works just like the x-values of **plt.plot**
# 2. lower-bound for y-values : sets the bottom of the shared area
# 3. upper-bound for y-values : sets the top of the shared area
#
# The **fill_between** is use to create a shaded error region, and then to plot the actual line over it.
#
# We can set the **alpha** keyword to a value between 0 and 1 in the **fill_between** call for transparency so that we can see the line underneath.

# %%
x_values = range(10)
y_values = [10, 12, 13, 13, 15, 19, 20, 22, 23, 29]
y_lower = [8, 10, 11, 11, 13, 17, 18, 20, 21, 27]
y_upper = [12, 14, 15, 15, 17, 21, 22, 24, 25, 31]

plt.fill_between(x_values, y_lower, y_upper, alpha=0.2)   # this is the shaded error
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# Having to calculate **y_lower** and **y_upper** by hand is time-consuming and if you try to subtract 2 from **y_values** you would get an error: *TypeError: unsupported operand type(s) -: 'list' and 'init*
#
# In order to correctly add or subtract from a list, we need to us *list comprehension*:

# %%
y_lower =[i-2 for i in y_values]

# %% [markdown]
# #### Example
# Below we look at a set of data representing MatplotSip's projected revenue per month for the next year in the variable **revenue**

# %%
months = range(12)
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
revenue = [16000, 14000, 17500, 19500, 21500, 21500, 22000, 23000, 20000, 19500, 18000, 16500]

plt.plot(months, revenue)

# ax = plt.subplot()
ax.set_xticks(months)
ax.set_xticklabels(month_names)

# since the data that is provided is only a projection and an estimate based on patterns of past years 
# we can say the actual revenue will probably be plus or minus 10% of each value.
y_lower = [i-0.1*i for i in revenue]
y_upper = [i+0.1*i for i in revenue]

plt.fill_between(months, y_lower, y_upper, alpha=0.2)


plt.show()

# %% [markdown]
# ## Pie Chart
#
# To display elements of a data set as proportions of a whole, we can use a pie chart.
#
# Pie charts are helpful for displaying data like:
# - Different ethnicities that make up a school district
# - Different macronutrients (carbohydrates, fat, protein) that make up a meal
# - Different responses to an online poll
#
# We can do this using the command **plt.pie**

# %%
budget_data = [500, 1000, 750, 300, 100]

plt.pie(budget_data)
plt.show()

# %% [markdown]
# #### Example
#
# MatplotSip keeps track of how many people pay by credit card, cash, Apple pay, or other methods. This is given in the **payment_method_names** and **payment_method_freqs** list

# %%
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs)
plt.show()

# %% [markdown]
# ## Pie Chart Labeling
#
# We need to understand what each slice of the pie represents. To do this, we can either:
# 1. Use a legend to label color
#
# OR
# 2. Put labels on the chart itself
#
# ### Method 1

# %%
budget_data = [500, 1000, 750, 300, 100]
budget_categories = ['marketing', 'payroll', 'engineering', 'design', 'misc']

plt.pie(budget_data)
plt.legend(budget_categories)
plt.show()

# %% [markdown]
# ### Method 2

# %%
plt.pie(budget_data, labels = budget_categories)
plt.show()

# %% [markdown]
# Another useful labeling tool for pie charts is adding the percentage of the total that each slice occupies. Matplotlib can add this automatically with the keyword **autopct**.
#
# We pass in *string formatting* instructions to format the labels how we want. Some common formats are:
# - **'%0.2f'** - 2 decimal places, like *4.08*
# - **'%0.2f%%'** - 2 decimal places, but with a percent sign at the end like *4.08%*.
# (you need two consecutive percent signs because the first one acts as an escape character, so that the second one gets displayed on the chart)
# - **'%d%%'** - rounded to the nearest **int** and with a percent sign at the end like *4%*

# %%
plt.pie(budget_data, labels=budget_categories, autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ## Histogram
#
# A histogram tells us how many values in a dataset fall between different sets of numbers (i.e., how many numbers fall between 0 and 10? Between 10 and 20? Between 20 and 30?). Each of these questions represents a bin, for instance, our first bin might be between 0 and 10.
#
# All bins in a histogram are always the same size. The *width* of each bin is the distance between the minimum and maximum values of each bin. In our example, the width of each bin would be 10.
#
# Each bin is represented by a different rectangle whose height is the number of elements from the dataset that fall within that bin.
#
# ![image.png](attachment:image.png)
#
# We use the **plt.hist** command to make a histogram.
#
# **plt.hist** finds the minimum and maximum values in your dataset and creates 10 equally-spaced bins between those values.
#
#         plt.hist(dataset)
#         plt.show()
#
# If we want more than 10 bins, we can use the keyword **bins** to set how many bins we want to divide the data into.
#
# The keyword **range** selects the minimum and maximum values to plot.
#
# For example, if we wanted to take our data from the last example and make a new historgram that just displayed the values from 66 to 69, divided into 40 bins (instead of 10) we could use this funciton to call:
#
#
#         plt.hist(dataset, range=(66, 69), bins=40)
#
# this would result in the a historgram that looks like this:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Multiple Historgrams
#
# If we want to compare two different distributions, we can put multiple histograms on the same plot. However, it can be hard to read two histograms on top of each other
#
# We have two ways we can do multiple histograms:
#
# ### Method 1
#
# 1. use the keyword **alpha**, which can be a value between 0 and 1. This sets the transparancy of the histogram. A value of 0 would make the bars entirely transparent. A value of 1 would make the bars completely opaque
#
#         plt.hist(a, range=(55, 75), bins=20, alpha=0.5)
#         plt.hist(b, range=(55, 75), bins=20, alpha=0.5)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Method 2
#
# 2. use the keyword **histype** with the argument ***'step'*** to draw just the outline of a histogram:
#
#         plt.hist(a, range=(55, 75), bins=20, histtype='step')
#         plt.hist(b, range=(55, 75), bins=20, histtype='step')
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Another problem we face is that our histograms might have different numbers of samples, making one much bigger than the other. I would be difficult to compare qualitatively, by adding a dataset **b** with a much bigger **size** value:
#         a = normal(loc=64, scale=2, size=10000)
#         b = normal(loc=70, scale=2, size=100000)
#
#         plt.hist(a, range=(55, 75), bins=20)
#         plt.hist(b, range=(55, 75), bins=20)
#         plt.show()
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To solve this, we can normalize our histograms using **density=True**. This command divides the height of each column by a constant such that the total shaded area of the histogram sums to 1.
#
#         a = normal(loc=64, scale=2, size=10000)
#         b = normal(loc=70, scale=2, size=100000)
#
#         plt.hist(a, range=(55, 75), bins=20, alpha=0.5, density=True)
#         plt.hist(b, range=(55, 75), bins=20, alpha=0.5, density=True)
#         plt.show()
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------------------
# # How to Select a Meaningful Visualization
#
# ## Brainstorming your visualization
#
# The three steps in the data visualization process are ***preparing***, ***isualizing***, and ***styling***
#
# During your brainstorming phase, you should consider two things:
# - The foucsing question you want to answer with your chart
# - The type of data that you want to visualize
#
#
#
# ## A Diagram of Diagrams!
# ![image.png](attachment:image.png)
#
# ## Chart Categories
# ### Composition charts
#
# Focusing Question: What are the part of some whole? What is the data made of?
#
# Datasets that work well: Data pertaining to probabilities, proportions, and percentages can be visualised as with the graphs in the composition category.
#
# Charts in this category illustrate the different data components and their percentages as part of a whole.
#
# ### Distribution Charts
#
# Datasets that work well: Data in large quantities and/or with an array of attributes works well for these types of charts.
#
# Visualizations in this category will allow you to see patterns, re-occurrences, and a clustering of data points.
#
# **Note:** a commonly seen distribution is a bell curve, also known as a normal distribution. A bell curve is a bell-shaped distribution where most of the values in the dataset crowd around the average (also known as the mean), therefore causing the curve to form. If you want to see how values in the data are "distributed" across variables, this choice would be best way to do that.
#
# ### Relationship Charts
#
# Focusing Question: How do variables releate to each other?
#
# Datasets that work well: Data with two or more variables can be displayed in these charts. These charts typically illustrate a *correlation** between two or more variables.
#
# You can communicate this relationship by mapping multiple variables in the same chart. Correlationn measures the strength of a relationship between variables
#
# ## Comparison Charts
#
# Focusing Question: How do variables compare to each other?
#
# Datasets that work well: Data must have multiple variables, and the visualizations in this category allow readers to compare those items against the others.
#
# For example: a line graph that has multiple lines, each belonging to a different variable. Mutli-colored bar charts are also a great way to compare items in data.

# %% [markdown]
# ----------

# %% [markdown]
# -----

# %% [markdown]
# # Examples
#
# Let’s imagine that you are working as a high school math teacher. You want to display important metrics about your current class and the ones you have taught in previous years, in order to understand patterns and trends that may not be visible from just seeing the numbers in a spreadsheet.

# %%
from matplotlib import pyplot as plt
import numpy as np

past_years_averages = [82, 84, 83, 86, 74, 84, 90]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]

plt.figure(figsize=(10, 8))
plt.bar(range(len(years)), past_years_averages, yerr=error, capsize = 10)
plt.axis([-0.5, 6.5, 70, 95])

#ax = plt.subplot()
ax.set_xticks(range(len(years)))
ax.set_xticklabels(years)

plt.title('Final Exam Averages')
plt.xlabel('Year')
plt.ylabel('Test Averages')

plt.show()

# %% [markdown]
# ## Side By Side Bars
# Now we display the differences in average test scores between students who went to two different middle schools before enrolling in your high school.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]

def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]

school_a_x = [0.8, 2.8, 4.8, 6.8, 8.8]
school_b_x = [1.6, 3.6, 5.6, 7.6, 9.6]

x_values_a = create_x(2, 0.8, 1, 5)
x_values_b = create_x(2, 0.8, 2, 5)

print(x_values_a)
print(x_values_b)

plt.bar(x_values_a, middle_school_a)
plt.bar(x_values_b, middle_school_b)

middle_x = [(a+b)/2.0 for a,b in zip(school_a_x, school_b_x)]

#ax = plt.subplot()
ax.set_xticks(middle_x)
ax.set_xticklabels(unit_topics)

plt.title('Test Averages on Different Units')
plt.xlabel('Unit')
plt.ylabel('Test Averages')

plt.show()
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8]
# [1.6, 3.6, 5.6, 7.6, 9.6]

# %% [markdown]
# ## Stacked Bars
# Now we are going to look in to the breakdown of students who got As, Bs, Cs, Ds, and Fs in each unit

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
As = [6, 3, 4, 3, 5]
Bs = [8, 12, 8, 9, 10]
Cs = [13, 12, 15, 13, 14]
Ds = [2, 3, 3, 2, 1]
Fs = [1, 0, 0, 3, 0]

x = range(5)

# The Bs bars will go on top of the As bars. The bottom bar of the Cs will be at an height of As + Bs 
# which we do using NumpPy (a scientific computing package) with the np.add function
# c_bottom will be the starting heights for the Cs
c_bottom = np.add(As, Bs)
d_bottom = np.add(c_bottom, Cs)
f_bottom = np.add(d_bottom, Ds)

plt.figure(figsize=(10,8))

plt.bar(x, As)
plt.bar(x, Bs, bottom=As)
plt.bar(x, Cs, bottom=c_bottom)
plt.bar(x, Ds, bottom=d_bottom)
plt.bar(x, Fs, bottom=f_bottom)

ax.set_xticks(range(len(unit_topics)))
ax.set_xticklabels(unit_topics)

plt.title('Grade Distribution')
plt.xlabel('Unit')
plt.ylabel('Number of Students')


plt.show()

# %% [markdown]
# ## Two Histograms on a Plot
# Now we look into displaying the breakdown of final exam scores between your first year of teaching vs your second year of teaching

# %%
from matplotlib import pyplot as plt

exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]
exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,72.26,73.23,92.6,66.22,70.09,77.2]

# Make your plot here
plt.figure(figsize=(10, 8))
plt.hist(exam_scores1, bins=12, density=True, histtype='step', linewidth=2)
plt.hist(exam_scores2, bins=12, density=True, histtype='step', linewidth=2)
plt.legend(["1st Yr Teaching", "2nd Yr Teaching"])


plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.title('Final Exam Score Distribution')
plt.savefig('my_histogram.png')
plt.show()

plt.show()

# %% [markdown]
# ## Labeled Pie Chart
#
# Now we display what students think the hardest topic covered throughout your math course is

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
num_hardest_reported = [1, 3, 10, 15, 1]

plt.pie(num_hardest_reported, labels=unit_topics, autopct='%df%%')
plt.title('Hardest Topics')
plt.savefig('my_pie_chart.png')

plt.show()

# %% [markdown]
# ## Line with Shaded Error
#
# We look into displaying the relationship between the time students say they studied and the scores they received on their final exams.

# %%
hours_reported =[3, 2.5, 2.75, 2.5, 2.75, 3.0, 3.5, 3.25, 3.25,  3.5, 3.5, 3.75, 3.75,4, 4.0, 3.75,  4.0, 4.25, 4.25, 4.5, 4.5, 5.0, 5.25, 5, 5.25, 5.5, 5.5, 5.75, 5.25, 4.75]
exam_scores = [52.53, 59.05, 61.15, 61.72, 62.58, 62.98, 64.99, 67.63, 68.52, 70.29, 71.33, 72.15, 72.67, 73.85, 74.44, 75.62, 76.81, 77.82, 78.16, 78.94, 79.08, 80.31, 80.77, 81.37, 85.13, 85.38, 89.34, 90.75, 97.24, 98.31]

plt.plot(exam_scores, hours_reported)

y_lower = [(x - 0.2*x) for x in hours_reported]
y_upper = [(x + 0.2*x) for x in hours_reported]

plt.fill_between(exam_scores, y_lower, y_upper, alpha=0.2)

plt.title('Time spent studying vs final exam scores')
plt.xlabel('Score')
plt.ylabel('Hours studying (self-reported)')
plt.savefig('my_line_graph.png')

plt.show()
