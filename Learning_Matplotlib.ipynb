# %% [markdown]
# # Introduction
# ---------------------
# **Matplotlib** is a Python library used to create charts and graphs.
#
# Before you start working with Matplotlib, we need to **import** it into our Python environment.

# %%
# Import Matplotlib in our Python environment

from matplotlib import pyplot as plt

# %% [markdown]
# ## Basic Line Plot
# Line graphs are basic that help visualise how a variable changes over time. Some possible data that would be displayed with a line graph:
# - average prices of gasoline over the past decade
# - weight of an individual over the past couple of months
# - average temperature along a line of longitude over different lattitudes
#
# The following code will create a simple graph using **.plot()** and display it using **.show()**:

# %%
x_values = [0, 1, 2, 3, 4]
y_values = [0, 1, 2, 3, 4]
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# **x_values** : is a variable holding a list of x-values for each point on our line graph
#
# **y_values** : is a variable holding a list of y-values for each point on our line graph
#
# **plt**      : is the name we have given to the Matplotlib module we have imported at the top of the code
#
# **plt.plot(x_values, y_values)** : will create the line graph
#
# **plt.show()** : will actually display the graph
#
# #### Example
#
# We are going to make a simple graph representing someone's spending on lunch over the past week. There are two lists defined **days** and **money_spent**:

# %%
days = [0, 1, 2, 3, 4, 5, 6]
money_spent = [10, 12, 12, 10, 14, 22, 24]

plt.plot(days, money_spent)
plt.show()

# %% [markdown]
# ## Basic Line Plot 2
#
# We can have multiple line plots displayed on the same set of axes. This can be very useful if we want to compare two datasets with the same scale and axis categories. Matplotlib will automatically place the two lines on the same axes and give them different colors if you call **plt.plot()** twice.
#
# Taking the previous example, we add a friend's lunch spending for comparison:

# %%
# Days of the week:
days = [0, 1, 2, 3, 4, 5, 6]

# Your Money:
money_spent = [10, 12, 12, 10, 14, 22, 24]

# Your Friend's Money:
money_spent_2 = [11, 14, 15, 15, 22, 21, 12]

# Plot your money:
plt.plot(days, money_spent)

# Plot your friend's money:
plt.plot(days, money_spent_2)

# Display the result:
plt.show()

# %% [markdown]
# #### Example

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

plt.plot(time, revenue)
plt.plot(time, costs)
plt.show()

# %% [markdown]
# ## Linestyles
#
# We can specify a different color for a line by using the keyword **color** with either an HTML color name or a HEX code:

# %%
plt.plot(days, money_spent, color='green')
plt.plot(days, money_spent_2, color='#AAAAAA')
plt.show()

# %% [markdown]
# We can also make a line dotted or dashed using keyword **linestyle**:

# %%
# Dashed
plt.plot(x_values, y_values, linestyle='--')
plt.show()

# %%
# Dotted:
plt.plot(x_values, y_values, linestyle=':')
plt.show()

# %%
# No line:
plt.plot(x_values, y_values, linestyle='')
plt.show()

# %% [markdown]
# We can also add a marker using the keyword **marker**:

# %%
# A circle:
plt.plot(x_values, y_values, marker='o')
plt.show()

# %%
# A square:
plt.plot(time, revenue, marker='s')

# A star:
plt.plot(time, costs, marker='*')

plt.show()

# %% [markdown]
# ## Axis and Labels
#
# It can be useful to zoom in or out of the plot, especially if there is some detail we want to address. To zoom, we can use **plt.axis()**. We use **plt.axis()** by feeding it a list as input. This should contain:
# 1. The minimum x-value displayed
# 2. The maximum x-value displayed
# 3. The minimum y-value displayed
# 4. The maximum y-value displayed
#
# **Example:** if we want to display a plot from x=0 to x=3 and from y=2 to y=5 we would call **plt.axis([0, 3, 2, 5])**

# %%
x=[0, 1, 2, 3, 4]
y=[0, 1, 3, 9, 16]
plt.plot(x, y)
plt.show()

# %%
x=[0, 1, 2, 3, 4]
y=[0, 1, 3, 9, 16]
plt.plot(x, y)
plt.axis([0, 3, 2, 5])
plt.show()

# %% [markdown]
# ## Labeling the Axes
#
# To label the x- and y-axes we use **plt.xlabel()** and **plt.ylabel()**. The plot title can be set by using **plt.title()**.
#
# **Example**: Below we look at an example for money spent on drinking coffee over the last 12 years

# %%
x=range(12)
y = [3000, 3005, 3010, 2900, 2950, 3050, 3000, 3100, 2980, 2980, 2920, 3010]
plt.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Dollars spent on Coffee ($)')
plt.title('My Last 12yrs of Coffee Drinking')
plt.show()

# %% [markdown]
# ## Subplots
#
# To display two lines side-by-side, rather than in the same set of x- and y-axes we use **subplots**. When we have multiple axes in the same picture, we call each set of axes a ***subplot***. The picture or object that contains all of the subplots is called a ***figure***.
#
# We can have many different subplots in the same figure, and we can lay them out in many different ways. Our layouts have rows and columns of subplots. For instance, the following figure has six subplots split into 2 rows and 3 columns:
# ![image.png](attachment:image.png)
#
# We can create subplots using **.subplot()**
#
# The command **plt.subplot()** needs three arguments to be passed into it:
# - The number of rows of subplots
# - The number of columns of subplots
# - The index of the subplot we want to create
#
# For instance, the command **plt.subplot(2, 3, 4)** would create "Subplot 4" from the figure above.
#
# Any **plt.plot()** that comes after **plt.subplot()** will create a line plot in the specified subplot for instance:

# %%
# Data sets
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

# First Subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, color='green')
plt.title('First Subplot')

# Second Subplot
plt.subplot(1, 2, 2)
plt.plot(x, y, color='steelblue')
plt.title('Second Subplot')

# Display both subplots
plt.show()

# %% [markdown]
# #### Example

# %%
months = range(12)
temperature = [36, 36, 39, 52, 61, 72, 77, 75, 68, 57, 48, 48]
flights_to_hawaii = [1200, 1300, 1100, 1450, 850, 750, 400, 450, 400, 860, 990, 1000]

# temperature vs months
plt.subplot(1,2,1)
plt.plot(months, temperature)
plt.xlabel('Month')
plt.ylabel('Temperature (F)')
plt.title('Temperature over the Year')

# flights to hawaii vs temperature
plt.subplot(1,2,2)
plt.plot(temperature, flights_to_hawaii, marker='o')
plt.xlabel('Temperature (F)')
plt.ylabel('Flight Timing')
plt.title('Hawaii Flights and Temperature')

plt.show()

# %% [markdown]
# ## Subplots Part 2
#
# When we put multiple subplots together, some elements can overlap and make the figure unreadable as seen in the previous example.
#
# We can customize the spacing between our subplots to make sure the figure we create is visible and easy to understand. To do this, we use the **plt.subplots_adjust()** command. **.subplots_adjust()** has some keyword arguments that can move your plots within the figure:
# - **left** : the left-side margin, with a default of 0.125. You can increase this number to make room for a y-axis label
# - **right** : the right-side margin, with a default of 0.9. You can increase this to make more room for the figure, or decrease it to make room for a legend
# - **bottom** : the bottom margin, with a default of 0.1. You can increase this to make room for tick mark labels or an x-axis label
# - **top** : the top margin, with a default of 0.9
# - **wspace** : the horizontal space between adjacent subplots, with a default of 0.2
# - **hspace** :  the vertical space between adjacent subplots, with a default of 0.2
#
# #### Example
# We are going to create a figure that has two rows of subplots. It should have:
# - one subplot in the top row
# - two subplots in the bottom row
# ![image.png](attachment:image.png)

# %%
x = range(7)
straight_line = [0, 1, 2, 3, 4, 5, 6]
parabola = [0, 1, 4, 9, 16, 25, 36]
cubic = [0, 1, 8, 27, 64, 125, 216]

# Top Plot (Index 1)
plt.subplot(2, 1, 1)
plt.plot(x, straight_line)
plt.title('Star Graph')

# Left Bottom Plot (Index 3)
plt.subplot(2, 2, 3)
plt.plot(x, parabola)
plt.title('Square Graph')

# Bottom Right Plot (Index 4)
plt.subplot(2, 2, 4)
plt.plot(x, cubic)
plt.title('Triangle Graph')

# Subplot Adjust
plt.subplots_adjust(wspace=0.35, bottom=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ## Legends
#
# We can label our graphs using legends by the command **plt.legend()**.
#
# The **legend** method takes a **list* with the labels to display.

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
plt.legend(['parabola', 'cubic'])
plt.show()

# %% [markdown]
# The command **plt.legend()** can also take a keyword argument **loc**, which will position the legend on the figure. The position values **loc** accepts:
#
#        Number Code     String
#             0           best
#             1           upper right
#             2           upper left
#             3           lower left
#             4           lower right
#             5           right
#             6           center left
#             7           center right
#             8           lower center
#             9           upper center
#             10          center
# **Note:** If you decide not to set a value for **loc** it will default to choosing the "best" location.

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
plt.legend(['parabola', 'cubic'], loc=6)
plt.show()

# %% [markdown]
# Sometimes, it's easier to label each line as we create it. If we want, we can use the keyword **label** inside of the **plt.plot()**. If we choose to do this, we don't pass any labels into **plt.legend()**

# %%
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16],
         label="parabola")
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64],
         label="cubic")
plt.legend(loc=6) # Still need this command! We don't pass labels but can still give location 
plt.show()

# %% [markdown]
# #### Example
# We plott three lines that represent the temperatures over the past year in three locations:
# - Hyrule (hyrule)
# - Kakariko (kakariko)
# - Gerudo Valley (gerudo)

# %%
months = range(12)
hyrule = [63, 65, 68, 70, 72, 72, 73, 74, 71, 70, 68, 64]
kakariko = [52, 52, 53, 68, 73, 74, 74, 76, 71, 62, 58, 54]
gerudo = [98, 99, 99, 100, 99, 100, 98, 101, 101, 97, 98, 99]

plt.plot(months, hyrule)
plt.plot(months, kakariko)
plt.plot(months, gerudo)
plt.xlabel('months')
plt.ylabel('temperature (F)')
plt.title('Temperature Graph')

legend_labels = ["Hyrule", "Kakariko", "Gerudo Valley"]

plt.legend(legend_labels)

plt.show()
